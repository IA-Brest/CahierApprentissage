# %% [markdown]
# # I- Préparation de données

# %% [markdown]
# ### 1- Informations sur les données

# %%
import pandas as pd
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# __About this file__: sur [Kaggle](https://www.kaggle.com/camnugent/california-housing-prices)
#
# 1. longitude: A measure of how far west a house is; a higher value is farther west
#
# 2. latitude: A measure of how far north a house is; a higher value is farther north
#
# 3. housingMedianAge: Median age of a house within a block; a lower number is a newer building
#
# 4. totalRooms: Total number of rooms within a block
#
# 5. totalBedrooms: Total number of bedrooms within a block
#
# 6. population: Total number of people residing within a block
#
# 7. households: Total number of households, a group of people residing within a home unit, for a block
#
# 8. medianIncome: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#
# 9. medianHouseValue: Median house value for households within a block (measured in US Dollars)
#
# 10. oceanProximity: Location of the house w.r.t ocean/sea

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### 2- Répartition des données

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=0)

test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11       -122.26     37.85                52.0       3503.0           752.0
# 1867     -119.95     38.95                 8.0        430.0           107.0
# 14030    -117.15     32.75                27.0       3166.0           867.0
# 6876     -118.10     34.07                36.0       1240.0           349.0
# 16351    -121.36     38.02                 5.0       2229.0           543.0
#
#        population  households  median_income  median_house_value  \
# 11         1504.0       734.0         3.2705            241800.0
# 1867         36.0        18.0         2.6250            187500.0
# 14030      1332.0       817.0         2.6742            171400.0
# 6876       1383.0       338.0         2.4931            170300.0
# 16351      1010.0       474.0         4.1719            206100.0
#
#       ocean_proximity
# 11           NEAR BAY
# 1867           INLAND
# 14030      NEAR OCEAN
# 6876        <1H OCEAN
# ...

# %%
housing = train_set
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19170    -122.62     38.40                10.0       9772.0          1308.0
# 18223    -122.08     37.41                20.0       1896.0           456.0
# 10083    -120.21     39.35                 7.0        914.0           159.0
# 4542     -118.20     34.03                52.0        583.0           157.0
# 1666     -122.25     38.03                15.0       3338.0           532.0
#
#        population  households  median_income  median_house_value  \
# 19170      3741.0      1242.0         6.5261            324700.0
# 18223      1069.0       436.0         4.6875            288900.0
# 10083        85.0        34.0         4.7917            187500.0
# 4542        730.0       174.0         1.4115            140600.0
# 1666       1834.0       520.0         5.6293            197600.0
#
#       ocean_proximity
# 19170       <1H OCEAN
# 18223        NEAR BAY
# 10083          INLAND
# 4542        <1H OCEAN
# ...

# %% [markdown]
# ### 3- Visualisation des données

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1,label="population", c="median_house_value", colormap='gist_rainbow',sharex=False, 
figsize=(10,7))

# %%
# Visualizing Geographical Data
import matplotlib.image as mpimg
california_img = mpimg.imread("california.png")
plt.imshow(california_img)

# %%
plt.imshow(california_img[:,:,1])

# %%
california_img.shape
# Out:
# (674, 594, 3)

# %%
min_long=housing['longitude'].min()
max_long= housing['longitude'].max()
min_lat=housing['latitude'].min()
max_lat= housing['latitude'].max()
print("min logitude : ",min_long)
print("max logitude : ",max_long)
print("min latitude : ",min_lat)
print("max latitude : ",max_lat)
# Out:
# min logitude :  -124.35
# max logitude :  -114.31
# min latitude :  32.54
# max latitude :  41.95

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.9, label="population", c="median_house_value", colormap='gist_rainbow',sharex=False, figsize=(10,7))
plt.imshow(california_img, extent=[-124.6509, -114.1315, 32.5121, 42.0126], alpha=0.9)
plt.legend()

# %%
corr_matrix = housing.corr()
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
print(corr_matrix["median_house_value"])
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### 4- Nettoyage de données

# %%
housing = train_set.drop("median_house_value", axis=1) # drop labels for training set
print(housing.head())
housing_labels = train_set["median_house_value"].copy()

print(housing.shape)

print(housing_labels.shape)
# print(housing_labels.head())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19170    -122.62     38.40                10.0       9772.0          1308.0
# 18223    -122.08     37.41                20.0       1896.0           456.0
# 10083    -120.21     39.35                 7.0        914.0           159.0
# 4542     -118.20     34.03                52.0        583.0           157.0
# 1666     -122.25     38.03                15.0       3338.0           532.0
#
#        population  households  median_income ocean_proximity
# 19170      3741.0      1242.0         6.5261       <1H OCEAN
# 18223      1069.0       436.0         4.6875        NEAR BAY
# 10083        85.0        34.0         4.7917          INLAND
# 4542        730.0       174.0         1.4115       <1H OCEAN
# 1666       1834.0       520.0         5.6293        NEAR BAY
# (13209, 9)
# (13209,)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13209 entries, 19170 to 5206
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           13209 non-null  float64
#  1   latitude            13209 non-null  float64
#  2   housing_median_age  13209 non-null  float64
#  3   total_rooms         13209 non-null  float64
#  4   total_bedrooms      13084 non-null  float64
#  5   population          13209 non-null  float64
#  6   households          13209 non-null  float64
#  7   median_income       13209 non-null  float64
#  8   ocean_proximity     13209 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.0+ MB

# %%
median = housing["total_bedrooms"].median()
housing["total_bedrooms"].fillna(median, inplace=True)
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13209 entries, 19170 to 5206
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           13209 non-null  float64
#  1   latitude            13209 non-null  float64
#  2   housing_median_age  13209 non-null  float64
#  3   total_rooms         13209 non-null  float64
#  4   total_bedrooms      13209 non-null  float64
#  5   population          13209 non-null  float64
#  6   households          13209 non-null  float64
#  7   median_income       13209 non-null  float64
#  8   ocean_proximity     13209 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.0+ MB

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
housing_cat = housing[["ocean_proximity"]]
housing[["ocean_proximity"]] = ordinal_encoder.fit_transform(housing_cat)
housing.head(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19170    -122.62     38.40                10.0       9772.0          1308.0
# 18223    -122.08     37.41                20.0       1896.0           456.0
# 10083    -120.21     39.35                 7.0        914.0           159.0
# 4542     -118.20     34.03                52.0        583.0           157.0
# 1666     -122.25     38.03                15.0       3338.0           532.0
# 648      -122.13     37.72                25.0       1134.0           153.0
# 4547     -118.20     34.02                42.0        498.0           120.0
# 12592    -121.51     38.52                30.0       3236.0           588.0
# 10179    -117.96     33.86                35.0       2181.0           371.0
# 6365     -117.97     34.17                35.0       5005.0           848.0
#
#        population  households  median_income  ocean_proximity
# 19170      3741.0      1242.0         6.5261              0.0
# ...

# %% [markdown]
# # II- Sélection et apprentissage du modèle

# %% [markdown]
# ### 1- Apprentissage des données

# %%
from sklearn.linear_model import LinearRegression
print(housing)
lin_reg = LinearRegression()
lin_reg.fit(housing, housing_labels)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19170    -122.62     38.40                10.0       9772.0          1308.0
# 18223    -122.08     37.41                20.0       1896.0           456.0
# 10083    -120.21     39.35                 7.0        914.0           159.0
# 4542     -118.20     34.03                52.0        583.0           157.0
# 1666     -122.25     38.03                15.0       3338.0           532.0
# ...          ...       ...                 ...          ...             ...
# 10866    -117.88     33.70                18.0       2135.0           373.0
# 14085    -117.10     32.76                52.0       2606.0           426.0
# 209      -122.23     37.79                40.0        930.0           199.0
# 4718     -118.38     34.06                31.0       4345.0          1158.0
# 5206     -118.28     33.93                41.0        936.0           257.0
#
# ...

# %% [markdown]
# ### 2- Evaluation du modèle d'apprentissage sur les données   d'apprentissage

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

housing_predictions = lin_reg.predict(housing)
# print("Labels:", list(housing_labels))
# print("Predictions:", housing_predictions)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 69087.97695136527

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing, housing_labels)
housing_predictions = tree_reg.predict(housing)
# print("Labels:", list(housing_labels))
# print("Predictions:", housing_predictions)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 0.0

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg, housing, housing_labels, scoring="neg_mean_squared_error", cv=10)


scores = np.sqrt(-scores)
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(scores)
# Out:
# Scores: [71158.36915984 68973.26588182 73257.053985   73359.27987972
#  67357.82870838 70006.25065878 72043.27161543 73266.44665944
#  75311.61394631 73719.47499802]
# Mean: 71845.28554927467
# Standard deviation: 2326.1954840818607

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lin_reg, housing, housing_labels,
scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [71533.78944035 73143.08479729 67236.91014059 68860.5785936
#  72376.30227439 69384.60398883 67291.38808361 68174.26319235
#  66444.8275442  67198.92618002]
# Mean: 69164.46742352055
# Standard deviation: 2266.3621914647642
