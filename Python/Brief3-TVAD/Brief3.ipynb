# %% [markdown]
# # Traitement, Visualisation et Analyse des données
#
#
# ## 1 - Déploiement de l’environnement
#
# Assurez-vous que les bibliothèques ci-dessous sont présentes dans votre environnement :
#
# Pandas Numpy SciPy Matplotlib
#
# - pip install panda numpy scipy matplotlib
#
# Une fois le module est installé, nous pouvons lancer un notebook pour commencer notre programme. Il faut tout d'abord importer le module.

# %%
# Importatioon du module pandas, numpy, scipy, matplotlib

import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mp

# %% [markdown]
# ## 2 - Sources de données : Manipulation
#
# Vous avez à disposition un répertoire nommé Data. Il existe dans ce répertoire un ensemble de fichiers(credit_immo.*) qui représentent les mêmes données avec des extensions différentes (csv, json, xls). En utilisant la ou les bibliothèques adéquates, chargez et visualisez ces fichiers.

# %%
# Overture des fichiers
#import os
#print(os.getcwd())

credit_immo_csv = pd.read_csv("./Data/credit_immo/credit_immo.csv", 
                       header = 0, sep = ",")
credit_immo_csv
# Out:
#       ID_NOM  Niv_Etude_Bac  age contrat_de_travail  Salaire  \
# 0       jean            3.0   45                CDI    40000
# 1    VANESSA            5.0   28                CDI    30500
# 2   TARCISSE            0.0   55                CDI    28000
# 3    TIBAULT            4.0   23                CDD    15000
# 4      GILES            0.0   33                CDD    27000
# 5      ETHAN            0.0   41            INTERIM    40000
# 6    LILIANE           -1.0   29                CDI    50000
# 7      GLODI           -3.0   24            INTERIM    29000
# 8   FLORIANE            NaN   26                CDI    44000
# 9      MARIE            3.0   37                CDI    45800
# 10   BAKAMBU            2.0   40                CDI    60000
# 11     FATOU            0.0   38                CDD    26000
# 12      WUAN           -3.0   39            INTERIM    29000
# 13      HUGO            0.0   31                CDI    43000
# ...

# %%
credit_immo_json = pd.read_json("./Data/credit_immo/credit_immo.json")
credit_immo_json
# Out:
#     Salaire    ID_NOM  dette_anterieure  apport contrat_de_travail  \
# 0     40000      jean              4000     0.3                CDI
# 1     30500   VANESSA              1320     0.1                CDI
# 2     28000  TARCISSE             40000     0.0                CDI
# 3     15000   TIBAULT                 0     0.1                CDD
# 4     27000     GILES              3000     0.1                CDD
# 5     40000     ETHAN              1000     0.0            INTERIM
# 6     50000   LILIANE              3000     0.0                CDI
# 7     29000     GLODI              5000     0.0            INTERIM
# 8     44000  FLORIANE                 0     0.1                CDI
# 9     45800     MARIE              2000     0.2                CDI
# 10    60000   BAKAMBU              1500     0.3                CDI
# 11    26000     FATOU              8000     0.4                CDD
# 12    29000      WUAN              4900     0.0            INTERIM
# ...

# %%
credit_immo_xls = pd.read_excel("./Data/credit_immo/credit_immo.xls")
credit_immo_xls
# Out:
#       ID_NOM  Niv_Etude_Bac  age contrat_de_travail  Salaire  \
# 0       jean            3.0   45                CDI    40000
# 1    VANESSA            5.0   28                CDI    30500
# 2   TARCISSE            0.0   55                CDI    28000
# 3    TIBAULT            4.0   23                CDD    15000
# 4      GILES            0.0   33                CDD    27000
# 5      ETHAN            0.0   41            INTERIM    40000
# 6    LILIANE           -1.0   29                CDI    50000
# 7      GLODI           -3.0   24            INTERIM    29000
# 8   FLORIANE            NaN   26                CDI    44000
# 9      MARIE            3.0   37                CDI    45800
# 10   BAKAMBU            2.0   40                CDI    60000
# 11     FATOU            0.0   38                CDD    26000
# 12      WUAN           -3.0   39            INTERIM    29000
# 13      HUGO            0.0   31                CDI    43000
# ...

# %% [markdown]
# En utilisant les bibliothèques adéquates, créer une base de données formée de 6 lignes et 4 colonnes.
# Les colonnes représentent respectivement les variables "taux_de_ventes, croissance_vente, ratio_benefice, ratio_perte".

# %%
dataset = pd.DataFrame(np.random.rand(6, 4), columns=(
    "taux_de_ventes",
    "croissance_vente",
    "ratio_benefice",
    "ratio_perte"
))

dataset
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 0        0.573046          0.783787        0.387540     0.906494
# 1        0.999113          0.351109        0.825599     0.007755
# 2        0.311731          0.271474        0.933683     0.721334
# 3        0.247536          0.826061        0.097766     0.368434
# 4        0.961252          0.564929        0.567007     0.704548
# 5        0.848201          0.977778        0.955251     0.135653

# %% [markdown]
# En utilisant la fonction dataset.reindex() et dataset.isnull(), introduire des données manquantes et récupérer les indices des valeurs manquantes.

# %%
data_manquante = dataset.reindex(range(0,10), fill_value=np.nan)
data_manquante
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 0        0.573046          0.783787        0.387540     0.906494
# 1        0.999113          0.351109        0.825599     0.007755
# 2        0.311731          0.271474        0.933683     0.721334
# 3        0.247536          0.826061        0.097766     0.368434
# 4        0.961252          0.564929        0.567007     0.704548
# 5        0.848201          0.977778        0.955251     0.135653
# 6             NaN               NaN             NaN          NaN
# 7             NaN               NaN             NaN          NaN
# 8             NaN               NaN             NaN          NaN
# 9             NaN               NaN             NaN          NaN

# %% [markdown]
# Puis remplacez les valeurs manquantes par 0 par exemple.

# %%
# Masque des valeurs manquantes :
data_manquante.isnull()
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 0           False             False           False        False
# 1           False             False           False        False
# 2           False             False           False        False
# 3           False             False           False        False
# 4           False             False           False        False
# 5           False             False           False        False
# 6            True              True            True         True
# 7            True              True            True         True
# 8            True              True            True         True
# 9            True              True            True         True

# %%
data_zerroed = data_manquante.fillna(0)
data_zerroed.isnull()
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 0           False             False           False        False
# 1           False             False           False        False
# 2           False             False           False        False
# 3           False             False           False        False
# 4           False             False           False        False
# 5           False             False           False        False
# 6           False             False           False        False
# 7           False             False           False        False
# 8           False             False           False        False
# 9           False             False           False        False

# %% [markdown]
# Puis supprimez ces valeurs manquantes.

# %%
data_droped = data_manquante.dropna()
data_droped
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 0        0.573046          0.783787        0.387540     0.906494
# 1        0.999113          0.351109        0.825599     0.007755
# 2        0.311731          0.271474        0.933683     0.721334
# 3        0.247536          0.826061        0.097766     0.368434
# 4        0.961252          0.564929        0.567007     0.704548
# 5        0.848201          0.977778        0.955251     0.135653

# %%
assert_frame_equal(dataset, data_droped)

# %% [markdown]
# ## 3 - Traitement des données
#
# Traitement des données renvoie à une série de processus qui permettent d’extraire de l’information ou de produire du savoir à partir de données brutes.
#
# Ces processus, une fois programmés, sont le plus souvent automatisés à l’aide d’ordinateurs.
#
# Les étapes pour le processus de traitement de données consiste à :
#
# 1. Importer les bibliothèques adéquates.
# 2. Importer le jeu de données (credit_immo.csv).
# 3. Transformer les valeurs manquantes en moyenne (SimpleImputer).
# 4. Encoder les valeurs catégoriques (LabelEncoder).
# 5. Fractionner le jeu de données pour l’entrainement et le test (Training and Test set).
# 6. Mise à l’échelle des features (StandardScaler).
#
# Vous avez à votre disposition un fichier nommé credit_immo.csv. Appliquez les étapes de prétraitement sur cette base de données.

# %% [markdown]
# 1. Importer les bibliothèques adéquates.

# %%
# Importatioon du module pandas, numpy, scipy, matplotlib

#import pandas as pd
#import scipy as sp
#import matplotlib as mp

import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# 2. Importer le jeu de données (credit_immo.csv).

# %%
redit_immo_csv = pd.read_csv("./Data/credit_immo/credit_immo.csv", 
                       header = 0, sep = ",")
credit_immo_csv
# Out:
#       ID_NOM  Niv_Etude_Bac   age contrat_de_travail  Salaire  \
# 0       jean            3.0  45.0                CDI    40000
# 1    VANESSA            5.0  28.0                CDI    30500
# 2   TARCISSE            0.0  55.0                CDI    28000
# 3    TIBAULT            4.0  23.0                CDD    15000
# 4      GILES            0.0  33.0                CDD    27000
# 5      ETHAN            0.0  41.0            INTERIM    40000
# 6    LILIANE           -1.0  29.0                CDI    50000
# 7      GLODI           -3.0  24.0            INTERIM    29000
# 8   FLORIANE            NaN  26.0                CDI    44000
# 9      MARIE            3.0  37.0                CDI    45800
# 10   BAKAMBU            2.0  40.0                CDI    60000
# 11     FATOU            0.0  38.0                CDD    26000
# 12      WUAN           -3.0  39.0            INTERIM    29000
# 13      HUGO            0.0  31.0                CDI    43000
# ...

# %% [markdown]
# 3. Transformer les valeurs manquantes en moyenne (SimpleImputer).

# %%
# Remplacer en utilisant la médiane
#df = credit_immo_csv.copy()
#median = df['Niv_Etude_Bac'].median()
#df['Niv_Etude_Bac'].fillna(median, inplace=True)
#print(df)

data = credit_immo_csv
imr = SimpleImputer(missing_values=np.nan, strategy='mean')
imr = imr.fit(data)
data_m = imr.transform(data).ravel()
data_m
#X = credit_immo_csv.iloc[:, :-1].values
#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
#imp_mean.fit(X)
#credit_immo_manquantes = imp_mean(credit_immo_csv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-bf55faafc685> in <module>
#       7 data = credit_immo_csv
#       8 imr = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 9 imr = imr.fit(data)
#      10 data_m = imr.transform(data).ravel()
#      11 data_m
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     247                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     248                                     "data:\n{}".format(self.strategy, ve))
# --> 249                 raise new_ve from None
#     250             else:
# ...

# %% [markdown]
# 4. Encoder les valeurs catégoriques (LabelEncoder).

# %% [markdown]
# 5. Fractionner le jeu de données pour l’entrainement et le test (Training and Test set).

# %% [markdown]
# X :
# Y :

# %% [markdown]
# 6. Mise à l’échelle des features (StandardScaler).

# %% [markdown]
# ## 4 - Visualisation de données
#
# Chargez le fichier Montant_Temps.csv

# %%
montant_temps = pd.read_csv("./Data/Montant_Temps.csv", 
                       header = 0, sep = ",")
montant_temps
# Out:
#     Montant_du_capitale  Temps
# 0                     1      5
# 1                    12      6
# 2                    13      7
# 3                     2      8
# 4                     3      9
# 5                     0     10
# 6                     1     11
# 7                     6     12
# 8                     7     13
# 9                     4     14
# 10                    5     15
# 11                   26     16
# 12                   27     17
# 13                   24     18
# 14                   25     19
# 15                   30     20
# 16                   31     21
# 17                   28     22
# 18                   29     23
# 19                   18     24
# 20                   19     25
# 21                   16     26
# 22                   17     27
# 23                   22     28
# 24                   23     29
# 25                   20     30
# 26                   21     31
# 27                   42     32
# 28                   43     33
# ...

# %% [markdown]
#  Puis en utilisation la fonction iloc, découpez vos données en données d’abscisses et d’ordonnées qui représentent respectivement le temps et le montant du capital.

# %%
capital = montant_temps.iloc[:,0:1]
capital_label = capital.columns[0]
capital_label
# Out:
# 'Montant_du_capitale'

# %%
temps = montant_temps.iloc[:,1:]
temps_label = temps.columns[0]
temps_label
# Out:
# 'Temps'

# %% [markdown]
# Puis tracez le montant du capital en fonction du temps (avec la focntion plot()) . Puis sauvegardez vos graphiques.

# %%
graphique_montant_temps = montant_temps.plot(x=temps_label, y=capital_label, kind="line")
graphique_montant_temps.get_figure().savefig('graphique_montant_temps.pdf')

# %% [markdown]
# ### 4.1 - Rajoutez du style à vos graphiques
#
# Annotez vos courbes et amusez vous avec les paramètres d’affichages pour changer les aspects des graphiques que vous avez crées.

# %%
mp.style.use('Solarize_Light2')
mp.rcParams['axes.facecolor'] = 'lightpink'
graphique_montant_temps = montant_temps.plot(x=temps_label, y=capital_label, title="Montant du Capital en fonction du Temps", kind="line", figsize=(10, 5), fontsize=26, use_index=True, subplots=True)
#

# %% [markdown]
# ### 4.2 - Visualisation de données sous forme de nuage de points
#
# Illustration de vos données en nuage de points est utilisé pour déterminer la solidité d’une relation entre deux variables numériques. Avec les bibliothèques de python, visualisez vos données sous forme de nuage de point.

# %%
graphique_montant_temps = montant_temps.plot(x=temps_label, y=capital_label, title="Montant du Capital en fonction du Temps", kind="scatter", figsize=(10, 5), fontsize=26, use_index=True, subplots=True)

# %% [markdown]
# ## 5 - Analyse de données
#
# ### 5.1 - Mesure de tendance centrale
#
# Mesure de tendance centrale est le nombre qui caractérise le centre d’une distribution et la position des diverses valeurs de la distribution par rapport à ce centre. Il s’agit ici de calculer la moyenne, le médiane et le mode d’une distribution. Vous avez à disposition le fichier nommé tendance_centrale.csv. Chargez ces données puis en utilisant les outils nécessaires appliquez la mesure de tendance centrale sur ces données.

# %%
tendance_centrale = pd.read_csv("./Data/tendance_centrale.csv", 
                       header = 0, sep = ",")
tendance_centrale
# Out:
#            Nom  Age  Rating
# 0      ANATOLE   55    4.53
# 1     Vincent    59    3.54
# 2      Brenda    55    3.98
# 3    Philippe    53    5.59
# 4      Michel    30    3.50
# 5     Tillier    59    4.90
# 6   Blanchard    53    3.80
# 7        perez   34    3.78
# 8        théo    40    5.98
# 9     cyprien    30    4.80
# 10   manuella    53    4.30
# 11   LEGGERET    49    3.95
# 12       perez   34    3.78
# 13    sestre     40    5.98
# 14      Fazal    30    4.80
# 15      Donald   53    4.30
# 16     Estelle   49    3.95

# %% [markdown]
# moyenne

# %%
tendance_centrale.mean()
# Out:
# Age       45.647059
# Rating     4.438824
# dtype: float64

# %% [markdown]
# médiane

# %%
tendance_centrale.median()
# Out:
# Age       49.0
# Rating     4.3
# dtype: float64

# %% [markdown]
# mode d’une distribution

# %% [markdown]
# ### 5.2 - Analyse de la variance
#
# En statistique, l’analyse de la variance est un modèle statistique utilisé pour comparer les moyennes d’échantillons. Ce test s’applique lorsque l’on mesure une ou plusieurs variables explicatives catégorielle (appelées alors facteurs de variabilité, leurs différentes modalités étant parfois appelées « niveaux ») qui ont de l’influence sur la loi d’une variable continue à expliquer. Faites une analyse de variance sur le jeu de données issu de tendance_centrale.csv.
#
# ### 5.3 - Analyse de corrélations
#
# L’objectif de l’analyse de corrélation est étudier la liaison entre deux variables quantitative. Soient X et Y deux grandeurs statistiques quantitatives observées. On souhaite :
#
# - Déterminer s’il existe une relation entre X et Y .
# - Caractériser la forme de la liaison(la relation) entre X et Y (positive ou négative,linéaire ou non linéaire,monotone ou non monotone)
# - Tester si la liaison est statistiquement significative
# - Quantifier l’intensité de la liaison
#
# Utlilisez le jeu de données (iris.csv)
#
# #### 5.3.2 - Analyse graphique :
#
# L’analyse graphique est une bonne manière de comprendre les différentes caractéristiques énumérées ci-dessus. Le graphique "nuage de points" est l’outil privilégié. Nous plaçons en abscisse la variable X, en ordonnée la variable Y, chaque observation est positionnée dans le repère ainsi constitué. L’intérêt est multiple : nous pouvons situer les proximités entre les individus;
#
# - Etudier la forme globale des points, voir notamment s’il existe une forme de liaison ou de régularité;
# - Détecter visuellement les points qui s’écartent des autres, les observations atypiques;
# - Vérifier s’il n’y a pas de regroupement suspects, laissant entendre qu’il y a en réalité une troisième variable qui influence le positionnement des individus. . .
# - A partir de la base de données qui vous est fournie, illustrez quelques types de liaisons qui peuvent exister entre 2 variables.
#
# Utlilisez le jeu de données (iris.csv)
#
# #### 5.3.3 - Analyse mathématique :
#
# coefficient de corrélation de Pearson Le coefficient de corrélation linéaire simple, dit de Bravais-Pearson(ou de Pearson), est une normalisation de la covariance par le produit des écarts-type des variables :
#
#     r(x,y )= COV(X,Y) / (E(X) x E(Y))
#
# Avec les outils et bibliothèques de Python, calculez le coefficient de corrélation de Pearson sur la base de données fournie et interprétez les résultats.
#
# Utlilisez le jeu de données (iris.csv)

# %% [markdown]
# ## Pour aller loin
#
# Essayer d'integrer toutes ces fonctionnalités dans une interface graphique et qui permet de visualiser les différentes extensions des fichier pour ne plus à avoir passer par la console.
#
# ## Modalités pédagogiques
#
# Le projet est lancé le 05/01 et se termine le 11/01.
#
# Le travail se fait en groupe de 2-3 personnes.
#
# ## Critères de performance
#
# Le code Python doit fonctionner comme décrit dans le contexte.
#
# ## Modalités d'évaluation
#
# Revue de code avec le formateur.
#
# ## Livrables
#
# Un code python qui marche et qui réalise les différentes étapes (bien structuré).
#
# Une interface si c'est possible.
